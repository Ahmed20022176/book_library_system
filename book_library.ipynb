# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed20022176/book_library_system/blob/main/book_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class library:
    def __init__(self):
        self.books=[]

    def add_book(self,name,price):
        self.name= name
        self.price= price
        self.books.append({"name": self.name, "price": self.price})
        print("Book add successfully")

    def remove_book(self,name):
        for book in self.books:
            if book["name"] == name:
                self.books.remove(book)
                print("Book removed successfully.")
                return

        print("Book not found.")
    def show_book(self):
        if len(self.books) == 0:
            print("No books available.")
        else:
            print("\n--------- BOOKS ---------")
            for book in self.books:
                print("Name:", book["name"])
                print("Price:", book["price"])
                print("------------------------")

obj=library()

while True:
    print("\n--------- LIBRARY ---------")
    print("1. Add Book")
    print("2. Remove Book")
    print("3. View Books")
    print("4. Exit")

    choice = input("Enter your choice: ").strip()

    if choice == "1":
        name = input("Enter Book Name: ").strip()
        price = input("Enter Book Price: ").strip()

        obj.add_book(name, price)

    elif choice == "2":
        name = input("Enter Book Name: ").strip()

        obj.remove_book(name)
    elif choice =="3":
        obj.show_book()


    elif choice == "4":
        print("Library closed.")
        break
    else:
        print("Invalid Number")
# Out:
# --------- LIBRARY ---------
# 1. Add Book
# 2. Remove Book
# 3. View Books
# 4. Exit
# Enter your choice: 1
# Enter Book Name: English
# Enter Book Price: 200
# Book add successfully
#
# --------- LIBRARY ---------
# 1. Add Book
# 2. Remove Book
# 3. View Books
# 4. Exit
# Enter your choice: 1
# Enter Book Name: Math
# Enter Book Price: 250
# Book add successfully
#
# --------- LIBRARY ---------
# 1. Add Book
# 2. Remove Book
# 3. View Books
# 4. Exit
# Enter your choice: 3
#
# --------- BOOKS ---------
# Name: English
# Price: 200
# ------------------------
# Name: Math
# Price: 250
# ------------------------
#
# --------- LIBRARY ---------
# 1. Add Book
# 2. Remove Book
# 3. View Books
# 4. Exit
# Enter your choice: 2
# Enter Book Name: English
# Book removed successfully.
#
# --------- LIBRARY ---------
# 1. Add Book
# 2. Remove Book
# 3. View Books
# 4. Exit
# Enter your choice: 4
# Library closed.
